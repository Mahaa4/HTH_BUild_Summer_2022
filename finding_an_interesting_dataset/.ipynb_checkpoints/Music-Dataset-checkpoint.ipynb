# %% [markdown]
# QUESTIONS TO ANSWER
# 1. Most commonly used Tags
# 2. How many famous songs are there from each decade
# 3. How many songs hit 1B since COVID-19 time i.e 2020
# 4. Which length of video would get the most engagements ( Views, Likes, Comments )
# 5. Best day of the week to publish a famous music video
# 6. How many spanish songs are there in the dataset
# 7. Does being a top labe(more subscribers) give you more views in a shorter amount of time?
# 8. Are the comments and likes on each video equal or do they differ significantly?
# 9. How many BTS songs are on the list

# %%
import pandas
import seaborn as sns

music = pandas.read_csv("1B-YouTube.csv")

#pandas.options.display.max_columns = None
#pandas.options.display.max_rows = None

music
# Out:
#      Unnamed: 0                                    thumbnailUrl  \
# 0             0  https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg
# 1             1  https://i.ytimg.com/vi/CZt-rVn2BJs/default.jpg
# 2             2  https://i.ytimg.com/vi/VuNIsY6JdUw/default.jpg
# 3             3  https://i.ytimg.com/vi/msSc7Mv0QHY/default.jpg
# 4             4  https://i.ytimg.com/vi/dQw4w9WgXcQ/default.jpg
# ..          ...                                             ...
# 311         311  https://i.ytimg.com/vi/nfs8NYg7yQM/default.jpg
# 312         312  https://i.ytimg.com/vi/xTlNMmZKwpA/default.jpg
# 313         313  https://i.ytimg.com/vi/0yW7w8F2TVA/default.jpg
# 314         314  https://i.ytimg.com/vi/pB-5XG-DbAA/default.jpg
# 315         315  https://i.ytimg.com/vi/CTFtOOh47oo/default.jpg
#
#             published_at       channel_name                channel_id  \
# 0    2020-08-21 03:58:10        HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA
# ...

# %%
#How many spanish songs are there in the dataset
spanish_songs = music['artist']
spanish_songs
# Out:
# 0                                                    BTS
# 1      PRANJAL DAHIYA,AMAN JAJI,RENUKA PANWAR,MUKESH ...
# 2                                           Taylor Swift
# 3                                                 J.Geco
# 4                                            Rick Astley
# 5                                         Dwayne Johnson
# 6                                                    BTS
# 7                                   Emraan Hashmi, Yukti
# 8                                                  Nelly
# 9                                        Michael Jackson
# 10                                             BLACKPINK
# 11                  ,Tanishk B, Neha Kakkar,Dhvani, Ikka
# 12                                         Ariana Grande
# 13                                             BLACKPINK
# 14                                            Bruno Mars
# 15                                              Bon Jovi
# ...

# %%
#How many BTS songs are on the list
bts_song = len(music[(music['artist'] == 'BTS')])
bts_song

#young_adults = titanic_data [ (titanic_data ['Age'] >= 17)  &  (titanic_data ['Age'] <= 25) ]
# Out:
# 5

# %%
#Does video duration affect the views?
import seaborn as sns
# For Plot 1
sns.violinplot(y = music['video_duration'], x = music['views'])

#sns.jointplot(x = music['views'], y = music['likes'], kind = 'hex')
# Out:
# <AxesSubplot:xlabel='views', ylabel='video_duration'>

# %%
#How many songs hit 1B since COVID-19 time i.e 2020
